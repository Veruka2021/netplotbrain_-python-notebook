# %%
pip install netplotbrain
# Out:
# Collecting netplotbrain
#   Downloading netplotbrain-0.3.0-py3-none-any.whl (2.1 MB)
# Collecting templateflow>=0.6.3
#   Downloading templateflow-23.1.0-py3-none-any.whl (461 kB)
# Collecting nibabel>=3.1.0
#   Using cached nibabel-5.2.0-py3-none-any.whl (3.3 MB)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\vero_\anaconda3\lib\site-packages (from netplotbrain) (1.22.4)
# Requirement already satisfied: matplotlib>=3.3.3 in c:\users\vero_\anaconda3\lib\site-packages (from netplotbrain) (3.7.4)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\vero_\anaconda3\lib\site-packages (from netplotbrain) (1.7.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vero_\anaconda3\lib\site-packages (from matplotlib>=3.3.3->netplotbrain) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vero_\anaconda3\lib\site-packages (from matplotlib>=3.3.3->netplotbrain) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vero_\anaconda3\lib\site-packages (from matplotlib>=3.3.3->netplotbrain) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vero_\anaconda3\lib\site-packages (from matplotlib>=3.3.3->netplotbrain) (4.48.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\vero_\anaconda3\lib\site-packages (from matplotlib>=3.3.3->netplotbrain) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vero_\anaconda3\lib\site-packages (from matplotlib>=3.3.3->netplotbrain) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vero_\anaconda3\lib\site-packages (from matplotlib>=3.3.3->netplotbrain) (2.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vero_\anaconda3\lib\site-packages (from matplotlib>=3.3.3->netplotbrain) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vero_\anaconda3\lib\site-packages (from matplotlib>=3.3.3->netplotbrain) (2.8.1)
# Requirement already satisfied: six in c:\users\vero_\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.3.3->netplotbrain) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\vero_\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.3->netplotbrain) (3.4.1)
# Collecting pybids>=0.15.2
#   Downloading pybids-0.16.4-py3-none-any.whl (14.9 MB)
# Requirement already satisfied: requests in c:\users\vero_\anaconda3\lib\site-packages (from templateflow>=0.6.3->netplotbrain) (2.25.1)
# Requirement already satisfied: tqdm in c:\users\vero_\anaconda3\lib\site-packages (from templateflow>=0.6.3->netplotbrain) (4.65.0)
# Collecting formulaic<0.6,>=0.2.4
#   Downloading formulaic-0.5.2-py3-none-any.whl (77 kB)
# Requirement already satisfied: pandas>=0.25.2 in c:\users\vero_\anaconda3\lib\site-packages (from pybids>=0.15.2->templateflow>=0.6.3->netplotbrain) (1.5.2)
# Requirement already satisfied: click>=8.0 in c:\users\vero_\anaconda3\lib\site-packages (from pybids>=0.15.2->templateflow>=0.6.3->netplotbrain) (8.1.7)
# Requirement already satisfied: sqlalchemy>=1.3.16 in c:\users\vero_\anaconda3\lib\site-packages (from pybids>=0.15.2->templateflow>=0.6.3->netplotbrain) (1.4.7)
# Collecting bids-validator>=1.11
#   Downloading bids_validator-1.14.0-py3-none-any.whl (21 kB)
# Collecting num2words>=0.5.5
#   Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
# Requirement already satisfied: colorama in c:\users\vero_\anaconda3\lib\site-packages (from click>=8.0->pybids>=0.15.2->templateflow>=0.6.3->netplotbrain) (0.4.4)
# Collecting graphlib-backport>=1.0.0
#   Downloading graphlib_backport-1.0.3-py3-none-any.whl (5.1 kB)
# Requirement already satisfied: wrapt>=1.0 in c:\users\vero_\anaconda3\lib\site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.15.2->templateflow>=0.6.3->netplotbrain) (1.12.1)
# Collecting astor>=0.8
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting interface-meta>=1.2.0
#   Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\vero_\anaconda3\lib\site-packages (from formulaic<0.6,>=0.2.4->pybids>=0.15.2->templateflow>=0.6.3->netplotbrain) (4.7.1)
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vero_\anaconda3\lib\site-packages (from pandas>=0.25.2->pybids>=0.15.2->templateflow>=0.6.3->netplotbrain) (2021.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\vero_\anaconda3\lib\site-packages (from sqlalchemy>=1.3.16->pybids>=0.15.2->templateflow>=0.6.3->netplotbrain) (1.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vero_\anaconda3\lib\site-packages (from requests->templateflow>=0.6.3->netplotbrain) (1.26.18)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vero_\anaconda3\lib\site-packages (from requests->templateflow>=0.6.3->netplotbrain) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\vero_\anaconda3\lib\site-packages (from requests->templateflow>=0.6.3->netplotbrain) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vero_\anaconda3\lib\site-packages (from requests->templateflow>=0.6.3->netplotbrain) (2023.7.22)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=76a61bdeb74709244c9b04378fc2e9203749091df97ed467a048edae31097bb5
#   Stored in directory: c:\users\vero_\appdata\local\pip\cache\wheels\56\ea\58\ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: interface-meta, graphlib-backport, docopt, astor, num2words, nibabel, formulaic, bids-validator, pybids, templateflow, netplotbrain
# Successfully installed astor-0.8.1 bids-validator-1.14.0 docopt-0.6.2 formulaic-0.5.2 graphlib-backport-1.0.3 interface-meta-1.3.0 netplotbrain-0.3.0 nibabel-5.2.0 num2words-0.5.13 pybids-0.16.4 templateflow-23.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import packages
import netplotbrain
import pandas as pd
# Define the nodes
nodes_df = pd.DataFrame({'x': [40, 10, 30, -15, -25], 
                         'y': [50, 40, -10, -20, 20], 
                         'z': [20, 30, -10, -15, 30]})
# Call netplotbrain to plot
netplotbrain.plot(nodes=nodes_df, arrowaxis=None)
# Out:
# (<Figure size 216x216 with 1 Axes>, [<Axes3D: title={'center': 'Left'}>])

# %%
# Define the nodes (5 example nodes)
nodes_df = pd.DataFrame(data={'x': [40, 10, 30, -15, -25], 
                              'y': [50, 40, -10, -20, 20], 
                              'z': [20, 30, -10, -15, 30], 
                              'communities': [1, 1, 1, 2, 2], 
                              'degree_centrality': [1, 1, 0.2, 0.8, 0.4]})
# Call netplotbrain to plot
netplotbrain.plot(
    nodes=nodes_df,
    node_size='degree_centrality',
    node_color='communities',
    arrowaxis=None,
    node_scale=100)
# Out:
# (<Figure size 216x288 with 3 Axes>,
#  [<Axes3D: title={'center': 'Left'}>, <Axes: >, <Axes: >])

# %%
# Define the atlas by key value words of TemplateFlow name
nodes={'template': 'MNI152NLin2009cAsym',
         'atlas': 'Schaefer2018',
         'desc': '400Parcels7Networks',
         'resolution': 1}
## Template (nifti or string)
netplotbrain.plot(
    nodes=nodes,
    arrowaxis=None)
# Out:
# Downloading https://templateflow.s3.amazonaws.com/tpl-MNI152NLin2009cAsym/tpl-MNI152NLin2009cAsym_res-01_atlas-Schaefer2018_desc-400Parcels7Networks_dseg.nii.gz
# 100%|██████████| 479k/479k [00:00<00:00, 1.38MB/s]
# (<Figure size 216x216 with 1 Axes>, [<Axes3D: title={'center': 'Left'}>])

# %%
# Define the atlas by key value words of TemplateFlow name
nodes={'template': 'MNI152NLin2009cAsym',
         'atlas': 'Schaefer2018',
         'desc': '400Parcels7Networks',
         'resolution': 1}
# Plot
netplotbrain.plot(
    nodes=nodes,
    arrowaxis=None,
    node_type='parcel')
# Out:
# (<Figure size 216x216 with 1 Axes>, [<Axes3D: title={'center': 'Left'}>])

# %%
# Define the nodes (5 example nodes)
nodes_df = pd.DataFrame(data={'x': [40, 10, 30, -15, -25], 
                              'y': [50, 40, -10, -20, 20], 
                              'z': [20, 30, -10, -15, 30], 
                              'communities': [1, 1, 1, 2, 2], 
                              'degree_centrality': [1, 1, 0.2, 0.8, 0.4]})
# Define the edges 
edges_df = pd.DataFrame(data={'i': [0, 0, 1, 1, 3], 
                              'j': [1, 2, 2, 3, 4]})
# Call netplotbrain to plot
netplotbrain.plot(
    nodes=nodes_df,
    edges=edges_df,
    node_color='communities',
    arrowaxis=None,
    node_scale=150)
# Out:
# (<Figure size 216x252 with 2 Axes>,
#  [<Axes3D: title={'center': 'Left'}>, <Axes: >])

# %%
# Import packages
# Define the nodes (5 example nodes)
nodes_df = pd.DataFrame(data={'x': [40, 10, 30, -15, -25], 
                              'y': [50, 40, -10, -20, 20], 
                              'z': [20, 30, -10, -15, 30], 
                              'communities': [1, 1, 1, 2, 2], 
                              'degree_centrality': [1, 1, 0.2, 0.8, 0.4]})
# Define the edges 
edges_df = pd.DataFrame(data={'i': [0, 0, 1, 1, 3], 
                              'j': [1, 2, 2, 3, 4]})
# Call netplotbrain to plot
netplotbrain.plot(
    nodes=nodes_df,
    edges=edges_df,
    node_color='communities',
    arrowaxis=None,
    node_scale=150)
# Out:
# (<Figure size 216x252 with 2 Axes>,
#  [<Axes3D: title={'center': 'Left'}>, <Axes: >])

# %%
# Define the nodes (5 example nodes)
nodes_df = pd.DataFrame(data={'x': [40, 10, 30, -15, -25], 
                              'y': [50, 40, -10, -20, 20], 
                              'z': [20, 30, -10, -15, 30], 
                              'communities': [1, 1, 1, 2, 2], 
                              'degree_centrality': [1, 1, 0.2, 0.8, 0.4]})
# Define the edges 
edges_df = pd.DataFrame(data={'i': [0, 0, 1, 1, 3], 
                              'j': [1, 2, 2, 3, 4]})
# Call netplotbrain to plot
netplotbrain.plot(
    nodes=nodes_df,
    edges=edges_df,
    node_color='communities',
    arrowaxis=None,
    node_scale=150)
# Out:
# (<Figure size 216x252 with 2 Axes>,
#  [<Axes3D: title={'center': 'Left'}>, <Axes: >])

# %%
#increasing voxelsize
netplotbrain.plot(
    template='MNI152NLin6Asym',
    template_style='filled',
    template_voxelsize=3,
    arrowaxis=None)
#renders in ca 24 seconds 

# However, note that an excessive increase of voxelsize can degrade spatial resolution.
# Out:
# Downloading https://templateflow.s3.amazonaws.com/tpl-MNI152NLin6Asym/tpl-MNI152NLin6Asym_res-01_desc-brain_T1w.nii.gz
# 100%|██████████| 3.29M/3.29M [00:00<00:00, 3.42MB/s]
# (<Figure size 216x216 with 1 Axes>, [<Axes3D: title={'center': 'Left'}>])

# %%
# further increasing voxelsize
netplotbrain.plot(
    template='MNI152NLin6Asym',
    template_style='filled',
    template_voxelsize=7,
    arrowaxis=None)
    
# renders in ca. 3 seconds

# %%
# Import all necessary files
import pandas as pd
import numpy as np
import netplotbrain
import matplotlib.pyplot as plt
import templateflow.api as tf
import itertools
# Set random seed for reproducibility
np.random.seed(2022)

# %%
atlas = {'template': 'MNI152NLin2009cAsym',
         'atlas': 'Schaefer2018',
        'desc': '100Parcels7Networks'}
atlasinfo = tf.get(extension='.tsv', **atlas)
atlasinfo = pd.read_csv(atlasinfo, sep='\t')
# Resolution argument needed in atlas later nii.gz file
atlas['resolution'] = 1
# Parse the info in to get network names
networks = list(map(lambda x: x.split('_')[2], atlasinfo.name.values))
atlasinfo['yeo7networks'] = networks
# Rename longer network names
atlasinfo['yeo7networks'].replace('DorsAttn', 'DA', inplace=True)
atlasinfo['yeo7networks'].replace('SalVentAttn', 'VA', inplace=True)
atlasinfo['yeo7networks'].replace('Default', 'DMN', inplace=True)
atlasinfo['yeo7networks'].replace('SomMot', 'SM', inplace=True)

# %%
# create empty cognitive matrix
edges = np.random.normal(0, 0.025, [100, 100])

# Set within network connectivity to be stronger
for network in atlasinfo['yeo7networks'].unique():
    idx =  atlasinfo[atlasinfo['yeo7networks']==network].index
    idx_pairs = np.array(list(itertools.combinations(idx, 2)))
    edges[idx_pairs[:, 0], idx_pairs[:, 1]] = np.random.normal(0.5, 0.025, [len(idx_pairs)])
    edges[idx_pairs[:, 1], idx_pairs[:, 0]] = np.random.normal(0.5, 0.025, [len(idx_pairs)])

# %%
# Show what the connectivity matrix looks like
fig, ax = plt.subplots(1)
ax.imshow(edges)

# %%
# Plot it all
netplotbrain.plot(template='MNI152NLin2009cAsym',
                  nodes=atlas,
                  nodes_df=atlasinfo,
                  edges=edges,
                  view='LSs',
                  template_style='glass',
                  node_scale=25,
                  node_color='yeo7networks',
                  edge_threshold=0,
                  edge_thresholddirection='>',
                  seed=2022)
# Out:
# (<Figure size 648x252 with 4 Axes>,
#  [<Axes3D: title={'center': 'Left'}>,
#   <Axes3D: title={'center': 'Superior'}>,
#   <Axes3D: >,
#   <Axes: >])
